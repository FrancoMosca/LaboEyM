# %% [markdown]
# | Distancia (en metros) | Campo magnético |
# | :------: | :------: |
# |   -0,38   | 0,1080  |
# |   -0,36   |  0,1082   |
# |   -0,34   |  0,1086   |
# |   -0,32   |  0,1086   |
# |   -0,30   |   0,1080   |
# |   -0,12   |  0,1084   |
# |    0     |  0,1086   |
# |   0,12    | 0,1081  |
# |   0,20    |  0,1083   |
# |   0,28    |  0,1081   |
#
# | Distancia (en metros) | Campo magnético |
# | :------: | :------: |
# |   -0,38   |  0,1090   |
# |   -0,30    |  0,1110   |
# |   -0,24   |  0,1118   |
# |   -0,22   |  0,1130   |
# |   -0,20   |  0,1140   |
# |   -0,18   |  0,1155   |
# |   -0,16   |  0,1174   |
# |   -0,14   |  0,1200   |
# |   -0,12   |  0,1217   |
# |   -0,08    |  0,1200   |
# |   -0,06    |  0,1182   |
# |   -0,04    |  0,1166   |
# |    0     |  0,1150   |
# |    0,04     |  0,1158   |
# |    0,06     |  0,1174   |
# |    0,08     |  0,1190   |
# |    0,12    |  0,1218   |
# |    0,14    |  0,1211   |
# |    0,16    |  0,1190   |
# |    0,18    |  0,1170   |
# |    0,20    |  0,1150   |
# |    0,22    |  0,1130   |
# |    0,24    |  0,1113   |
# |    0,30    |  0,1089   |
# |    0,38    |  0,1069   |
#
# | Distancia (en metros) | Campo magnético |
# | :------: | :------: |
# |   -0,38   |  0,1088   |
# |   -0,36    |  0,1094   |
# |   -0,34   |  0,1096   |
# |   -0,30   |  0,1130   |
# |   -0,26   |  0,1140   |
# |   -0,22   |  0,1155   |
# |   -0,20   |  0,1174   |
# |   -0,16   |  0,1200   |
# |   -0,12   |  0,1217   |
# |   -0,08    |  0,1200   |
# |   -0,06    |  0,1182   |
# |   -0,02    |  0,1166   |
# |    0     |  0,1150   |
# |   0,02   |  0,1088   |
# |   0,06    | 0,1094   |
# |   0,08   |  0,1096   |
# |   0,12   |  0,1130   |
# |   0,16   |  0,1140   |
# |   0,20   |  0,1155   |
# |   0,22   |  0,1174   |
# |   0,26   |  0,1200   |
# |   0,30   |  0,1217   |
# |   0,34    |  0,1200   |
# |   0,36    |  0,1182   |
# |   0,38    |  0,1166   |

# %%
valores_x_background = [-0.38, -0.36, -0.34, -0.32, -0.30, -0.12, 0, 0.12, 0.20, 0.28]
campo_magnetico_background = [0.1080,0.1082,0.1086,0.1086,0.1080,0.1084,0.1086,0.1081,0.1083,0.1081]

valores_x_tension = [-0.38, -0.30, -0.24, -0.22, -0.20, -0.18, -0.16, -0.14, -0.12, -0.08, -0.06, -0.04, 0.0, 0.04, 0.06, 0.08, 0.12, 0.14, 0.16, 0.18, 0.20, 0.22, 0.24, 0.30, 0.38]
campo_magnetico_tension = [0.1090, 0.1110, 0.1118, 0.1130, 0.1140, 0.1155, 0.1174, 0.1200, 0.1217, 0.1200, 0.1182, 0.1166, 0.1150, 0.1158, 0.1174, 0.1190, 0.1218, 0.1211, 0.1190, 0.1170, 0.1150, 0.1130, 0.1113, 0.1089, 0.1069]

valores_x_a_r = [-0.38, -0.36, -0.34, -0.30, -0.26, -0.22, -0.20, -0.16, -0.12, -0.08, -0.06, -0.02, 0.0, 0.02, 0.06, 0.08, 0.12, 0.16, 0.20, 0.22, 0.26, 0.30, 0.34, 0.36, 0.38]
campo_magnetico_a_r = [0.1088, 0.1094, 0.1096, 0.1130, 0.1140, 0.1155, 0.1174, 0.1200, 0.1217, 0.1200, 0.1182, 0.1166, 0.1150, 0.1088, 0.1094, 0.1096, 0.1130, 0.1140, 0.1155, 0.1174, 0.1200, 0.1217, 0.1200, 0.1182, 0.1166]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros
mu_0 = 4 * np.pi * 10**-7  # Permeabilidad del vacío (T*m/A)
I = 200e-3  # Corriente en amperios
N = 200  # Número de vueltas
r = 0.1  # Radio en metros

# Valores de x desde -0.5 m hasta 0.5 m
x = np.linspace(-0.5, 0.5, 1000)

# Ecuación del campo magnético
B = (mu_0 * N * I * r**2) / (2 * (r**2 + x**2)**(3/2))

# Graficar
plt.figure(figsize=(10, 6))
plt.plot(x, B, label='Campo Magnético (B)')
plt.title('Campo Magnético a lo largo del eje de una espira circular')
plt.xlabel('Distancia (m)')
plt.ylabel('Campo Magnético (T)')
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.grid()
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros
mu_0 = 4 * np.pi * 10**-7  # Permeabilidad del vacío (T*m/A)
I = 200e-3  # Corriente en amperios
N = 200  # Número de vueltas
r = 0.1  # Radio en metros
a= r/2

# Valores de x desde -0.5 m hasta 0.5 m
x = np.linspace(-0.5, 0.5, 5000)


B1 = (mu_0 * N * I * r**2) / (2 * (r**2 + (x+a)**2)**(3/2))
B2 = (mu_0 * N * I * r**2) / (2 * (r**2 + (x-a)**2)**(3/2))

# Ecuación del campo magnético
# BT = (mu_0 * N * I * r**2) / (2 * ((r**2 + (x+a)**2)**(3/2) + (r**2 + (x-a)**2)**(3/2)))
BT= B1 + B2

# Graficar
plt.figure(figsize=(10, 6))
plt.plot(x, BT, label='Campo Magnético (B)')
plt.title('Campo Magnético a lo largo del eje de una espira circular')
plt.xlabel('Distancia (m)')
plt.ylabel('Campo Magnético (T)')
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.grid()
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros
mu_0 = 4 * np.pi * 10**-7  # Permeabilidad del vacío (T*m/A)
I = 0  # Corriente en amperios
N = 200  # Número de vueltas
r = 0.1  # Radio en metros
a= 0.125

# Valores de x desde -0.5 m hasta 0.5 m
x = np.linspace(-0.5, 0.5, 5000)


B1 = (mu_0 * N * I * r**2) / (2 * (r**2 + (x+a)**2)**(3/2))
B2 = (mu_0 * N * I * r**2) / (2 * (r**2 + (x-a)**2)**(3/2))

# Ecuación del campo magnético
# BT = (mu_0 * N * I * r**2) / (2 * ((r**2 + (x+a)**2)**(3/2) + (r**2 + (x-a)**2)**(3/2)))
BT = B1 + B2

# Graficar
plt.figure(figsize=(10, 6))
plt.plot(x, BT, label='Campo Magnético (B)')
plt.title('Campo Magnético a lo largo del eje de una espira circular')
plt.xlabel('Distancia (m)')
plt.ylabel('Campo Magnético (T)')
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.grid()
plt.legend()
plt.show()
